# %%
os.listdir()
# Out:
# ['EDA.ipynb',
#  'test.csv',
#  '__pycache__',
#  'preprocessing.py',
#  'train.csv',
#  'assignment1_preprocessing.ipynb',
#  'assignment1_prediction_model']

# %%
import pandas as pd
import numpy as np

# %%
import preprocessing
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/yavuzhanyavuz/temp_repo/advanced-analytics-projects/Assignment1/EDA.ipynb Cell 3' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/yavuzhanyavuz/temp_repo/advanced-analytics-projects/Assignment1/EDA.ipynb#ch0000004?line=0'>1</a> import preprocessing
#
# File ~/temp_repo/advanced-analytics-projects/Assignment1/preprocessing.py:4, in <module>
#       2 import numpy as np
#       3 date_columns = ['property_scraped_at', 'host_since', 'reviews_first', 'reviews_last']
# ----> 4 train_df = pd.read_csv("Assignment1/train.csv", parse_dates=date_columns)
#       5 test_df = pd.read_csv("Assignment1/test.csv", parse_dates=date_columns)
#       7 def string_to_int(input_var):
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/yavuzhanyavuz/temp_repo/advanced-analytics-projects/Assignment1/EDA.ipynb Cell 3' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/yavuzhanyavuz/temp_repo/advanced-analytics-projects/Assignment1/EDA.ipynb#ch0000002?line=0'>1</a> import preprocessing
#
# File ~/temp_repo/advanced-analytics-projects/Assignment1/preprocessing.py:4, in <module>
#       2 import numpy as np
#       3 date_columns = ['property_scraped_at', 'host_since', 'reviews_first', 'reviews_last']
# ----> 4 train_df = pd.read_csv("Assignment1/train.csv", parse_dates=date_columns)
#       5 test_df = pd.read_csv("Assignment1/test.csv", parse_dates=date_columns)
#       7 def string_to_int(input_var):
#
# ...

# %%
preprocessing.tra
# Out:
#       property_id                                    property_name  \
# 0               1                    Chambre à louer,courte durée.
# 1               2  Urban Antwerp - Spacious & Authentic Herenhouse
# 2               3   comfortable apartment in friendly neighborhood
# 3               4                         Historical City Antwerp.
# 4               5                              Antwerp center city
# ...           ...                                              ...
# 6490         6496       Grand appartement Saint Gilles avec balcon
# 6491         6497              Chambre cosy dans une grande maison
# 6492         6498                      Comfy room in spacious loft
# 6493         6499                      Top floor room. Big & sunny
# 6494         6500                           house near city centre
#
#                                        property_summary  \
# 0     Je loue une chambre dans mon appartement "atyp...
# ...
